# %% [markdown]
# # Kaggle: Housing Prices
#
# In this notebook we explore the [housing prices kaggle challenge](https://www.kaggle.com/c/house-prices-advanced-regression-techniques) with Google Colab.
#
#
# This is the second notebook in the housing prices kaggle challenge.  Here we explore Deep Learning techniques for performing the regression.

# %% [markdown]
# To begin, we will clone the repo to have access to the kaggle dataset.

# %%
# !git clone https://github.com/demarley/figment
# Out:
# fatal: destination path 'figment' already exists and is not an empty directory.

# %% [markdown]
# ## Deep Learning Techniques
#
# Now that we've covered some basic analysis techniques and boosted decision trees, let's explore some deep learning techniques for doing the regression.
#
# To do this, we'll start with `keras+tensorflow` because they are well-supported by Google Colab.
# If there's time, we'll install `pytorch` and try that as well.

# %%
# plotting
import matplotlib.style
import matplotlib as mpl
mpl.style.use("default")
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

import numpy as np
import pandas as pd

np.random.seed(2019)

# %%
df = pd.read_csv("figment/data/housing_prices/train.csv");

# %% [markdown]
# ### Data Cleaning
#
# From the previous notebooks, we know there are changes we can make to the dataset.  For now we won't do those here.  We will just leave the features that are textual alone for the time being. Let's look at the correlation matrix and choose some of the features more correlated with `SalePrice` (of the features that have numerical data).

# %%
corrmat = df.corr()

fig,ax  = plt.subplots(figsize=(12,10))

opts    = {'cmap':plt.get_cmap("bwr"),'vmin':-1,'vmax':1}
heatmap = plt.pcolor(corrmat, **opts)
cbar    = plt.colorbar(heatmap, ax=ax)

labels = corrmat.columns.values

# shift location of ticks to center of the bins
ax.set_xticks(np.arange(len(labels))+0.5, minor=False);
ax.set_yticks(np.arange(len(labels))+0.5, minor=False);
ax.set_xticklabels(labels, fontsize=10, minor=False, ha='right', rotation=70);
ax.set_yticklabels(labels, fontsize=10, minor=False);

# %% [markdown]
# From this correlation matrix, let's choose some of the features most strongly correlated with `SalePrice`.  Then, split the data into a `training` and `validation` sets.
#
# This attempt will use a somewhat random pick of features.  We'll just look at features that have correlations greater than 0.25 with `SalePrice`.

# %%
strong_corrs = corrmat[np.abs(corrmat.SalePrice)>0.25].SalePrice
features = list(strong_corrs.index)
_ = features.remove("SalePrice")   # remove the target value from the inputs!
print(strong_corrs.sort_values())
# Out:
# LotArea         0.263843
# HalfBath        0.284108
# OpenPorchSF     0.315856
# 2ndFlrSF        0.319334
# WoodDeckSF      0.324413
# LotFrontage     0.351799
# BsmtFinSF1      0.386420
# Fireplaces      0.466929
# MasVnrArea      0.477493
# GarageYrBlt     0.486362
# YearRemodAdd    0.507101
# YearBuilt       0.522897
# TotRmsAbvGrd    0.533723
# FullBath        0.560664
# 1stFlrSF        0.605852
# TotalBsmtSF     0.613581
# GarageArea      0.623431
# GarageCars      0.640409
# GrLivArea       0.708624
# OverallQual     0.790982
# SalePrice       1.000000
# Name: SalePrice, dtype: float64

# %%
# split into test and training 
from sklearn.model_selection import train_test_split

df  = df.fillna(-1)
tmp = df.sample(frac=1) # shuffle the dataframe rows
tts = train_test_split(df[features].values,\
                       df['SalePrice'].values, \
                       test_size=0.25)
X_train,X_test,Y_train,Y_test = tts

# %% [markdown]
# ### Deep Learning with Keras
# Using `keras+tensorflow`, let's try to do a more sophisticated prediction.
#
# **Describe method.**

# %%
from keras.models import Sequential
from keras.layers import Dense

from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.metrics import explained_variance_score  # quantifying accuracy of regression

# %%
# Hyperparameters
# Initially, I'll just choose some random hyperparameters and will adjust it as needed
n_feats = len(features)
optimizer = 'adam'
loss = 'mse'
metrics = ['mse', 'mae', 'mape']
activation = 'relu'
n_hidden = 1
n_nodes  = 2*n_feats    # considering rectangular models at the moment
validation_split = 0.25

# %%
# Define the model
model = Sequential()
model.add(Dense(n_nodes, activation=activation, input_dim=n_feats))

for l in range(n_hidden):
    model.add(Dense(n_nodes, activation=activation))

model.add(Dense(1, activation='linear'))       # Output node
model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

# %%
# Fit to the training dataset
history = model.fit(X_train, Y_train, epochs=50, validation_split=validation_split, verbose=1)
# Out:
# Train on 821 samples, validate on 274 samples
# Epoch 1/50
# 821/821 [==============================] - 1s 703us/step - loss: 37567941139.3325 - mean_squared_error: 37567941139.3325 - mean_absolute_error: 176885.3309 - mean_absolute_percentage_error: 97.9588 - val_loss: 35559560692.7883 - val_mean_squared_error: 35559560692.7883 - val_mean_absolute_error: 173139.6827 - val_mean_absolute_percentage_error: 95.8788
# Epoch 2/50
# 821/821 [==============================] - 0s 189us/step - loss: 34468374755.0012 - mean_squared_error: 34468374755.0012 - mean_absolute_error: 168684.9547 - mean_absolute_percentage_error: 93.0982 - val_loss: 31965770864.1168 - val_mean_squared_error: 31965770864.1168 - val_mean_absolute_error: 163150.2693 - val_mean_absolute_percentage_error: 89.7902
# Epoch 3/50
# 821/821 [==============================] - 0s 193us/step - loss: 29817081915.8685 - mean_squared_error: 29817081915.8685 - mean_absolute_error: 155379.6467 - mean_absolute_percentage_error: 85.1630 - val_loss: 26339580546.8029 - val_mean_squared_error: 26339580546.8029 - val_mean_absolute_error: 146164.9942 - val_mean_absolute_percentage_error: 79.4343
# Epoch 4/50
# 821/821 [==============================] - 0s 188us/step - loss: 23256344181.8660 - mean_squared_error: 23256344181.8660 - mean_absolute_error: 133528.1114 - mean_absolute_percentage_error: 71.7121 - val_loss: 18495487357.1971 - val_mean_squared_error: 18495487357.1971 - val_mean_absolute_error: 118748.7272 - val_mean_absolute_percentage_error: 62.7076
# Epoch 5/50
# 821/821 [==============================] - 0s 188us/step - loss: 16266483475.0207 - mean_squared_error: 16266483475.0207 - mean_absolute_error: 104169.9099 - mean_absolute_percentage_error: 53.8801 - val_loss: 11322175644.9635 - val_mean_squared_error: 11322175644.9635 - val_mean_absolute_error: 86169.5495 - val_mean_absolute_percentage_error: 43.5783
# Epoch 6/50
# 821/821 [==============================] - 0s 187us/step - loss: 11593975352.7503 - mean_squared_error: 11593975352.7503 - mean_absolute_error: 76001.0709 - mean_absolute_percentage_error: 37.4682 - val_loss: 7380249487.8832 - val_mean_squared_error: 7380249487.8832 - val_mean_absolute_error: 62398.0071 - val_mean_absolute_percentage_error: 30.8692
# Epoch 7/50
# Epoch 43/50
# 821/821 [==============================] - 0s 195us/step - loss: 1987667335.3276 - mean_squared_error: 1987667335.3276 - mean_absolute_error: 29555.7081 - mean_absolute_percentage_error: 17.4857 - val_loss: 3137926121.5766 - val_mean_squared_error: 3137926121.5766 - val_mean_absolute_error: 34663.1568 - val_mean_absolute_percentage_error: 22.0751
# Epoch 44/50
# 821/821 [==============================] - 0s 199us/step - loss: 1958200618.7966 - mean_squared_error: 1958200618.7966 - mean_absolute_error: 30269.1026 - mean_absolute_percentage_error: 18.7333 - val_loss: 3100903784.6423 - val_mean_squared_error: 3100903784.6423 - val_mean_absolute_error: 33584.9741 - val_mean_absolute_percentage_error: 20.8758
# Epoch 45/50
# 821/821 [==============================] - 0s 196us/step - loss: 1911428992.0780 - mean_squared_error: 1911428992.0780 - mean_absolute_error: 28973.3328 - mean_absolute_percentage_error: 17.2428 - val_loss: 3070037173.2555 - val_mean_squared_error: 3070037173.2555 - val_mean_absolute_error: 33004.2182 - val_mean_absolute_percentage_error: 20.2022
# Epoch 46/50
# 821/821 [==============================] - 0s 199us/step - loss: 1894700188.6870 - mean_squared_error: 1894700188.6870 - mean_absolute_error: 28934.6119 - mean_absolute_percentage_error: 17.3861 - val_loss: 3119139400.8759 - val_mean_squared_error: 3119139400.8759 - val_mean_absolute_error: 33183.8946 - val_mean_absolute_percentage_error: 20.6605
# Epoch 47/50
# 821/821 [==============================] - 0s 205us/step - loss: 1863865882.9720 - mean_squared_error: 1863865882.9720 - mean_absolute_error: 28571.0110 - mean_absolute_percentage_error: 17.0278 - val_loss: 3135610938.8613 - val_mean_squared_error: 3135610938.8613 - val_mean_absolute_error: 33038.1401 - val_mean_absolute_percentage_error: 20.6178
# Epoch 48/50
# 821/821 [==============================] - 0s 196us/step - loss: 1834315933.4665 - mean_squared_error: 1834315933.4665 - mean_absolute_error: 28488.2954 - mean_absolute_percentage_error: 17.1644 - val_loss: 3145473823.7664 - val_mean_squared_error: 3145473823.7664 - val_mean_absolute_error: 32686.5716 - val_mean_absolute_percentage_error: 20.3001
# Epoch 49/50
# 821/821 [==============================] - 0s 196us/step - loss: 1812322831.4348 - mean_squared_error: 1812322831.4348 - mean_absolute_error: 28236.1856 - mean_absolute_percentage_error: 16.9761 - val_loss: 3148823570.6861 - val_mean_squared_error: 3148823570.6861 - val_mean_absolute_error: 32361.7218 - val_mean_absolute_percentage_error: 20.0077
# Epoch 50/50
# 821/821 [==============================] - 0s 193us/step - loss: 1792484705.8319 - mean_squared_error: 1792484705.8319 - mean_absolute_error: 27917.4348 - mean_absolute_percentage_error: 16.6214 - val_loss: 3169545868.1460 - val_mean_squared_error: 3169545868.1460 - val_mean_absolute_error: 32221.0636 - val_mean_absolute_percentage_error: 19.9662

# %%
# Plot the loss for training and validation sets
fig,ax = plt.subplots()

loss     = history.history['loss']
val_loss = history.history.get('val_loss')

x = range(1,len(loss)+1)
plt.plot(x,loss,    label='Training')
plt.plot(x,val_loss,label="Validation")

plt.xlabel('Epoch',ha='right',va='top',   position=(1,0))
plt.ylabel('Loss', ha='right',va='bottom',position=(0,1))

plt.legend(loc=0,numpoints=1)

# %%
predictions = model.predict(X_test).flatten()
values      = np.divide((np.asarray(predictions) - Y_test),Y_test)        # offsets to compare predicted and actual value

# %%
# Prediction
fig,ax = plt.subplots(2,1,figsize=(8,8))

plt.subplot(2,1,1)
plt.hist(values,bins=20,normed=True)
plt.xlabel("(Pred-Real)/Real",position=(1,0),ha='right')
plt.ylabel("AU",position=(0,1),ha='right')

plt.subplot(2,1,2)
plt.scatter(predictions,Y_test,color='b',edgecolor='k',alpha=0.5,label="Test Dataset");
plt.plot(Y_test,Y_test,color='r',label="Perfect")
plt.xlim(min(predictions)-10000,max(predictions)+10000)
plt.ylim(0,max(Y_test)+20000)
plt.xlabel("Predicted Sale Price",position=(1,0),ha='right')
plt.ylabel("Real Sale Price",position=(0,1),ha='right')
plt.legend()

print(r"Distribution = {0:.3f} $\pm$ {1:.4f}".format(np.mean(values),np.std(values)))
# Out:
# Distribution = 0.078 $\pm$ 0.2638

# %% [markdown]
# We can also quantify the output using the function `explained_variance_score` from `scikit-learn` that I just discovered!

# %%
explained_variance_score(Y_test,predictions)
# Out:
# 0.6730019315818158

# %% [markdown]
# So, as you can see, the predictions are not that great.  Let's modify the hyperparameters and try again.

# %%
# Hyperparameters
# Initially, I'll just choose some random hyperparameters and will adjust it as needed
n_feats = len(features)
optimizer = 'adam'
loss = 'mse'
metrics = ['mse', 'mae', 'mape']
activation = 'elu'
n_hidden = 2
n_nodes  = 3*n_feats    # considering rectangular models at the moment
validation_split = 0.25

# %%
# Define the model
model = Sequential()
model.add(Dense(n_nodes, activation=activation, input_dim=n_feats))

for l in range(n_hidden):
    model.add(Dense(n_nodes, activation=activation))

model.add(Dense(1, activation='linear'))       # Output node
model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

# %%
# Fit to the training dataset
history = model.fit(X_train, Y_train, epochs=50, validation_split=validation_split, verbose=1)
# Out:
# Train on 821 samples, validate on 274 samples
# Epoch 1/50
# 821/821 [==============================] - 1s 686us/step - loss: 37088276899.0792 - mean_squared_error: 37088276899.0792 - mean_absolute_error: 175543.3283 - mean_absolute_percentage_error: 97.0363 - val_loss: 33567446755.9708 - val_mean_squared_error: 33567446755.9708 - val_mean_absolute_error: 167493.7994 - val_mean_absolute_percentage_error: 92.3202
# Epoch 2/50
# 821/821 [==============================] - 0s 226us/step - loss: 27948892808.5749 - mean_squared_error: 27948892808.5749 - mean_absolute_error: 148507.7784 - mean_absolute_percentage_error: 80.8463 - val_loss: 18476022896.1168 - val_mean_squared_error: 18476022896.1168 - val_mean_absolute_error: 118180.5841 - val_mean_absolute_percentage_error: 62.0180
# Epoch 3/50
# 821/821 [==============================] - 0s 215us/step - loss: 12790369155.2741 - mean_squared_error: 12790369155.2741 - mean_absolute_error: 77474.5860 - mean_absolute_percentage_error: 38.5448 - val_loss: 5332396708.4380 - val_mean_squared_error: 5332396708.4380 - val_mean_absolute_error: 48430.6624 - val_mean_absolute_percentage_error: 24.7340
# Epoch 4/50
# Epoch 31/50
# 821/821 [==============================] - 0s 233us/step - loss: 1819044207.1620 - mean_squared_error: 1819044207.1620 - mean_absolute_error: 28185.4609 - mean_absolute_percentage_error: 16.7162 - val_loss: 3696398828.3796 - val_mean_squared_error: 3696398828.3796 - val_mean_absolute_error: 32810.1118 - val_mean_absolute_percentage_error: 21.2845
# Epoch 32/50
# 821/821 [==============================] - 0s 214us/step - loss: 1732409900.9013 - mean_squared_error: 1732409900.9013 - mean_absolute_error: 27404.2128 - mean_absolute_percentage_error: 16.3862 - val_loss: 3535528318.1314 - val_mean_squared_error: 3535528318.1314 - val_mean_absolute_error: 31292.8948 - val_mean_absolute_percentage_error: 19.5800
# Epoch 33/50
# 821/821 [==============================] - 0s 208us/step - loss: 1698084669.8952 - mean_squared_error: 1698084669.8952 - mean_absolute_error: 27355.1022 - mean_absolute_percentage_error: 16.3888 - val_loss: 3363004801.8686 - val_mean_squared_error: 3363004801.8686 - val_mean_absolute_error: 30614.0098 - val_mean_absolute_percentage_error: 18.1452
# Epoch 34/50
# 821/821 [==============================] - 0s 218us/step - loss: 1680201576.7698 - mean_squared_error: 1680201576.7698 - mean_absolute_error: 26882.6596 - mean_absolute_percentage_error: 16.1012 - val_loss: 3482160478.3650 - val_mean_squared_error: 3482160478.3650 - val_mean_absolute_error: 30649.1225 - val_mean_absolute_percentage_error: 18.7559
# Epoch 35/50
# 821/821 [==============================] - 0s 214us/step - loss: 1689240505.8417 - mean_squared_error: 1689240505.8417 - mean_absolute_error: 26906.5116 - mean_absolute_percentage_error: 16.1359 - val_loss: 3407777280.0000 - val_mean_squared_error: 3407777280.0000 - val_mean_absolute_error: 30480.1868 - val_mean_absolute_percentage_error: 18.1969
# Epoch 36/50
# 821/821 [==============================] - 0s 223us/step - loss: 1672044930.4166 - mean_squared_error: 1672044930.4166 - mean_absolute_error: 26949.0868 - mean_absolute_percentage_error: 16.1061 - val_loss: 3613505558.4234 - val_mean_squared_error: 3613505558.4234 - val_mean_absolute_error: 30741.0874 - val_mean_absolute_percentage_error: 19.1448
# Epoch 37/50
# 821/821 [==============================] - 0s 223us/step - loss: 1663014513.1108 - mean_squared_error: 1663014513.1108 - mean_absolute_error: 26863.3073 - mean_absolute_percentage_error: 16.1618 - val_loss: 3529768294.7737 - val_mean_squared_error: 3529768294.7737 - val_mean_absolute_error: 30354.3489 - val_mean_absolute_percentage_error: 18.4778
# Epoch 38/50
# 821/821 [==============================] - 0s 218us/step - loss: 1694506724.2485 - mean_squared_error: 1694506724.2485 - mean_absolute_error: 27048.0771 - mean_absolute_percentage_error: 16.2182 - val_loss: 3676011687.2409 - val_mean_squared_error: 3676011687.2409 - val_mean_absolute_error: 30589.8504 - val_mean_absolute_percentage_error: 19.0611
# Epoch 39/50
# 821/821 [==============================] - 0s 211us/step - loss: 1667267973.7686 - mean_squared_error: 1667267973.7686 - mean_absolute_error: 26727.6416 - mean_absolute_percentage_error: 15.9673 - val_loss: 3494169234.6861 - val_mean_squared_error: 3494169234.6861 - val_mean_absolute_error: 30265.9067 - val_mean_absolute_percentage_error: 18.1486
# 821/821 [==============================] - 0s 224us/step - loss: 1633480983.1523 - mean_squared_error: 1633480983.1523 - mean_absolute_error: 26691.4939 - mean_absolute_percentage_error: 16.0434 - val_loss: 3538869032.1752 - val_mean_squared_error: 3538869032.1752 - val_mean_absolute_error: 29977.6837 - val_mean_absolute_percentage_error: 18.0902
# Epoch 49/50
# 821/821 [==============================] - 0s 220us/step - loss: 1627267998.7138 - mean_squared_error: 1627267998.7138 - mean_absolute_error: 26490.4456 - mean_absolute_percentage_error: 15.7820 - val_loss: 3845287011.0365 - val_mean_squared_error: 3845287011.0365 - val_mean_absolute_error: 30562.8855 - val_mean_absolute_percentage_error: 19.3468
# Epoch 50/50
# 821/821 [==============================] - 0s 216us/step - loss: 1641970365.1937 - mean_squared_error: 1641970365.1937 - mean_absolute_error: 26613.1976 - mean_absolute_percentage_error: 16.0709 - val_loss: 3687894087.0073 - val_mean_squared_error: 3687894087.0073 - val_mean_absolute_error: 29932.9802 - val_mean_absolute_percentage_error: 18.4388

# %%
predictions = model.predict(X_test).flatten()
values      = np.divide((np.asarray(predictions) - Y_test),Y_test)        # offsets to compare predicted and actual value

# %%
# Prediction
fig,ax = plt.subplots(2,1,figsize=(8,8))

plt.subplot(2,1,1)
plt.hist(values,bins=20,normed=True)
plt.xlabel("(Pred-Real)/Real",position=(1,0),ha='right')
plt.ylabel("AU",position=(0,1),ha='right')

plt.subplot(2,1,2)
plt.scatter(predictions,Y_test,color='b',edgecolor='k',alpha=0.5,label="Test Dataset");
plt.plot(Y_test,Y_test,color='r',label="Perfect")
plt.xlim(min(predictions)-10000,max(predictions)+10000)
plt.ylim(0,max(Y_test)+20000)
plt.xlabel("Predicted Sale Price",position=(1,0),ha='right')
plt.ylabel("Real Sale Price",position=(0,1),ha='right')
plt.legend()

evs = explained_variance_score(Y_test,predictions)

print(r"Distribution = {0:.3f} $\pm$ {1:.4f} :: {2:.3f}".format(np.mean(values),np.std(values),evs))
# Out:
# Distribution = 0.049 $\pm$ 0.2544 :: 0.712

# %%
# plot the loss and validation sets vs epoch
fig,ax = plt.subplots()

loss     = history.history['loss']
val_loss = history.history.get('val_loss')

x = range(1,len(loss)+1)
plt.plot(x,loss,    label='Training')
plt.plot(x,val_loss,label="Validation")

plt.xlabel('Epoch',ha='right',va='top',   position=(1,0))
plt.ylabel('Loss', ha='right',va='bottom',position=(0,1))

plt.legend(loc=0,numpoints=1)

# %% [markdown]
# By modifying the hyperparameters we're able to do a little better (smaller RMS and larger `evaluation_variance_score`).
# However, it does appear that the loss of the training and validation samples begins to diverge, so there might be some hints of overtraining here.
#
#
# #### Scaling the Inputs
#
# Now let's try again, with scaled inputs.  I'll also modify the parameters inline to test different architectures.

# %%
# Develop the scaling on the training dataset, and then apply the same shift to the test
# scale features
scaler = MinMaxScaler()
scaler.fit(X_train)

# scale target values
scaler_target = MinMaxScaler()
scaler_target.fit(Y_train.reshape(-1,1))
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
# Scale values
X_test_scale  = scaler.transform(X_test)
Y_test_scale  = scaler_target.transform([Y_test])
X_train_scale = scaler.transform(X_train)
Y_train_scale = scaler_target.transform([Y_train])

# %%
# Hyperparameters
# Initially, I'll just choose some random hyperparameters and will adjust it as needed
n_feats = len(features)
optimizer = 'adam'
loss = 'mse'
metrics = ['mse', 'mae', 'mape']
activation = 'elu'
n_hidden = 2
n_nodes  = 3*n_feats    # considering rectangular models at the moment
validation_split = 0.25

# Define the model
model = Sequential()
model.add(Dense(n_nodes, activation=activation, input_dim=n_feats))

for l in range(n_hidden):
    model.add(Dense(n_nodes, activation=activation))

model.add(Dense(1, activation='linear'))       # Output node
model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

# Fit to the training dataset
history = model.fit(X_train_scale, Y_train_scale.flatten(), epochs=50, validation_split=validation_split, verbose=1)
# Out:
# Train on 821 samples, validate on 274 samples
# Epoch 1/50
# 821/821 [==============================] - 1s 737us/step - loss: 0.1028 - mean_squared_error: 0.1028 - mean_absolute_error: 0.2398 - mean_absolute_percentage_error: 331424.0878 - val_loss: 0.0114 - val_mean_squared_error: 0.0114 - val_mean_absolute_error: 0.0816 - val_mean_absolute_percentage_error: 58.8913
# Epoch 2/50
# 821/821 [==============================] - 0s 216us/step - loss: 0.0097 - mean_squared_error: 0.0097 - mean_absolute_error: 0.0759 - mean_absolute_percentage_error: 123851.5407 - val_loss: 0.0083 - val_mean_squared_error: 0.0083 - val_mean_absolute_error: 0.0674 - val_mean_absolute_percentage_error: 44.7487
# Epoch 3/50
# 821/821 [==============================] - 0s 205us/step - loss: 0.0044 - mean_squared_error: 0.0044 - mean_absolute_error: 0.0463 - mean_absolute_percentage_error: 104766.5308 - val_loss: 0.0051 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0441 - val_mean_absolute_percentage_error: 27.6661
# Epoch 4/50
# 821/821 [==============================] - 0s 204us/step - loss: 0.0040 - mean_squared_error: 0.0040 - mean_absolute_error: 0.0442 - mean_absolute_percentage_error: 105411.1184 - val_loss: 0.0050 - val_mean_squared_error: 0.0050 - val_mean_absolute_error: 0.0425 - val_mean_absolute_percentage_error: 27.4040
# Epoch 5/50
# 821/821 [==============================] - 0s 205us/step - loss: 0.0036 - mean_squared_error: 0.0036 - mean_absolute_error: 0.0418 - mean_absolute_percentage_error: 82257.8036 - val_loss: 0.0048 - val_mean_squared_error: 0.0048 - val_mean_absolute_error: 0.0403 - val_mean_absolute_percentage_error: 25.6292
# Epoch 6/50
# 821/821 [==============================] - 0s 220us/step - loss: 0.0032 - mean_squared_error: 0.0032 - mean_absolute_error: 0.0388 - mean_absolute_percentage_error: 57095.9661 - val_loss: 0.0047 - val_mean_squared_error: 0.0047 - val_mean_absolute_error: 0.0395 - val_mean_absolute_percentage_error: 25.7230
# Epoch 7/50
# 821/821 [==============================] - 0s 225us/step - loss: 0.0030 - mean_squared_error: 0.0030 - mean_absolute_error: 0.0372 - mean_absolute_percentage_error: 53940.7522 - val_loss: 0.0046 - val_mean_squared_error: 0.0046 - val_mean_absolute_error: 0.0384 - val_mean_absolute_percentage_error: 24.5141
# Epoch 8/50
# 821/821 [==============================] - 0s 241us/step - loss: 0.0028 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0351 - mean_absolute_percentage_error: 34784.2155 - val_loss: 0.0048 - val_mean_squared_error: 0.0048 - val_mean_absolute_error: 0.0396 - val_mean_absolute_percentage_error: 25.8057
# Epoch 9/50
# 821/821 [==============================] - 0s 222us/step - loss: 0.0027 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0342 - mean_absolute_percentage_error: 27976.8176 - val_loss: 0.0046 - val_mean_squared_error: 0.0046 - val_mean_absolute_error: 0.0380 - val_mean_absolute_percentage_error: 24.5726
# Epoch 10/50
# 821/821 [==============================] - 0s 223us/step - loss: 0.0027 - mean_squared_error: 0.0027 - mean_absolute_error: 0.0346 - mean_absolute_percentage_error: 30860.3384 - val_loss: 0.0045 - val_mean_squared_error: 0.0045 - val_mean_absolute_error: 0.0366 - val_mean_absolute_percentage_error: 23.5004
# Epoch 11/50
# 821/821 [==============================] - 0s 227us/step - loss: 0.0028 - mean_squared_error: 0.0028 - mean_absolute_error: 0.0351 - mean_absolute_percentage_error: 15857.7218 - val_loss: 0.0051 - val_mean_squared_error: 0.0051 - val_mean_absolute_error: 0.0422 - val_mean_absolute_percentage_error: 27.1345
# Epoch 12/50
# 821/821 [==============================] - 0s 217us/step - loss: 0.0026 - mean_squared_error: 0.0026 - mean_absolute_error: 0.0329 - mean_absolute_percentage_error: 26789.1171 - val_loss: 0.0044 - val_mean_squared_error: 0.0044 - val_mean_absolute_error: 0.0350 - val_mean_absolute_percentage_error: 22.2475
# Epoch 13/50
# 821/821 [==============================] - 0s 234us/step - loss: 0.0024 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0315 - mean_absolute_percentage_error: 18145.8875 - val_loss: 0.0045 - val_mean_squared_error: 0.0045 - val_mean_absolute_error: 0.0364 - val_mean_absolute_percentage_error: 23.1861
# Epoch 14/50
# 821/821 [==============================] - 0s 221us/step - loss: 0.0024 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0308 - mean_absolute_percentage_error: 24861.4042 - val_loss: 0.0041 - val_mean_squared_error: 0.0041 - val_mean_absolute_error: 0.0340 - val_mean_absolute_percentage_error: 20.2422
# Epoch 15/50
# 821/821 [==============================] - 0s 224us/step - loss: 0.0025 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0325 - mean_absolute_percentage_error: 20561.2183 - val_loss: 0.0057 - val_mean_squared_error: 0.0057 - val_mean_absolute_error: 0.0485 - val_mean_absolute_percentage_error: 30.9803
# Epoch 16/50
# 821/821 [==============================] - 0s 226us/step - loss: 0.0031 - mean_squared_error: 0.0031 - mean_absolute_error: 0.0388 - mean_absolute_percentage_error: 13482.5109 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0380 - val_mean_absolute_percentage_error: 22.1323
# Epoch 17/50
# 821/821 [==============================] - 0s 215us/step - loss: 0.0025 - mean_squared_error: 0.0025 - mean_absolute_error: 0.0333 - mean_absolute_percentage_error: 1938.6236 - val_loss: 0.0039 - val_mean_squared_error: 0.0039 - val_mean_absolute_error: 0.0327 - val_mean_absolute_percentage_error: 19.6410
# Epoch 18/50
# 821/821 [==============================] - 0s 223us/step - loss: 0.0023 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0308 - mean_absolute_percentage_error: 11430.3018 - val_loss: 0.0040 - val_mean_squared_error: 0.0040 - val_mean_absolute_error: 0.0325 - val_mean_absolute_percentage_error: 20.0872
# Epoch 19/50
# 821/821 [==============================] - 1s 1ms/step - loss: 0.0022 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0299 - mean_absolute_percentage_error: 17485.6942 - val_loss: 0.0042 - val_mean_squared_error: 0.0042 - val_mean_absolute_error: 0.0337 - val_mean_absolute_percentage_error: 21.3560
# Epoch 20/50
# 821/821 [==============================] - 0s 235us/step - loss: 0.0022 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0292 - mean_absolute_percentage_error: 13107.2330 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0338 - val_mean_absolute_percentage_error: 21.4275
# Epoch 21/50
# 821/821 [==============================] - 0s 221us/step - loss: 0.0021 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0285 - mean_absolute_percentage_error: 9868.4975 - val_loss: 0.0040 - val_mean_squared_error: 0.0040 - val_mean_absolute_error: 0.0315 - val_mean_absolute_percentage_error: 19.9296
# Epoch 22/50
# 821/821 [==============================] - 0s 224us/step - loss: 0.0022 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0297 - mean_absolute_percentage_error: 13500.6041 - val_loss: 0.0038 - val_mean_squared_error: 0.0038 - val_mean_absolute_error: 0.0308 - val_mean_absolute_percentage_error: 18.9279
# Epoch 23/50
# 821/821 [==============================] - 0s 219us/step - loss: 0.0022 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0287 - mean_absolute_percentage_error: 24843.0492 - val_loss: 0.0038 - val_mean_squared_error: 0.0038 - val_mean_absolute_error: 0.0305 - val_mean_absolute_percentage_error: 19.1596
# Epoch 24/50
# 821/821 [==============================] - 0s 213us/step - loss: 0.0021 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0288 - mean_absolute_percentage_error: 2928.8524 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - val_mean_absolute_error: 0.0302 - val_mean_absolute_percentage_error: 18.2957
# Epoch 25/50
# 821/821 [==============================] - 0s 215us/step - loss: 0.0021 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0285 - mean_absolute_percentage_error: 2558.2640 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0340 - val_mean_absolute_percentage_error: 21.4791
# Epoch 26/50
# 821/821 [==============================] - 0s 230us/step - loss: 0.0024 - mean_squared_error: 0.0024 - mean_absolute_error: 0.0332 - mean_absolute_percentage_error: 10079.3490 - val_loss: 0.0039 - val_mean_squared_error: 0.0039 - val_mean_absolute_error: 0.0319 - val_mean_absolute_percentage_error: 18.8481
# Epoch 27/50
# 821/821 [==============================] - 0s 222us/step - loss: 0.0022 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0303 - mean_absolute_percentage_error: 3277.8056 - val_loss: 0.0049 - val_mean_squared_error: 0.0049 - val_mean_absolute_error: 0.0423 - val_mean_absolute_percentage_error: 26.8402
# Epoch 28/50
# 821/821 [==============================] - 0s 218us/step - loss: 0.0022 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0313 - mean_absolute_percentage_error: 21763.8996 - val_loss: 0.0039 - val_mean_squared_error: 0.0039 - val_mean_absolute_error: 0.0305 - val_mean_absolute_percentage_error: 18.7389
# Epoch 29/50
# 821/821 [==============================] - 0s 234us/step - loss: 0.0022 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0290 - mean_absolute_percentage_error: 20395.6524 - val_loss: 0.0038 - val_mean_squared_error: 0.0038 - val_mean_absolute_error: 0.0305 - val_mean_absolute_percentage_error: 19.0329
# Epoch 30/50
# 821/821 [==============================] - 0s 239us/step - loss: 0.0022 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0307 - mean_absolute_percentage_error: 17132.4140 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - val_mean_absolute_error: 0.0337 - val_mean_absolute_percentage_error: 21.5954
# Epoch 31/50
# 821/821 [==============================] - 0s 250us/step - loss: 0.0019 - mean_squared_error: 0.0019 - mean_absolute_error: 0.0266 - mean_absolute_percentage_error: 18411.7750 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - val_mean_absolute_error: 0.0293 - val_mean_absolute_percentage_error: 18.1778
# Epoch 32/50
# 821/821 [==============================] - 0s 221us/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0273 - mean_absolute_percentage_error: 1710.6687 - val_loss: 0.0040 - val_mean_squared_error: 0.0040 - val_mean_absolute_error: 0.0307 - val_mean_absolute_percentage_error: 19.3330
# Epoch 33/50
# 821/821 [==============================] - 0s 222us/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0278 - mean_absolute_percentage_error: 25783.5608 - val_loss: 0.0039 - val_mean_squared_error: 0.0039 - val_mean_absolute_error: 0.0306 - val_mean_absolute_percentage_error: 19.1409
# Epoch 34/50
# 821/821 [==============================] - 0s 219us/step - loss: 0.0021 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0295 - mean_absolute_percentage_error: 1082.2605 - val_loss: 0.0038 - val_mean_squared_error: 0.0038 - val_mean_absolute_error: 0.0313 - val_mean_absolute_percentage_error: 18.8818
# Epoch 35/50
# 821/821 [==============================] - 0s 228us/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0276 - mean_absolute_percentage_error: 5354.6664 - val_loss: 0.0038 - val_mean_squared_error: 0.0038 - val_mean_absolute_error: 0.0298 - val_mean_absolute_percentage_error: 18.2055
# Epoch 36/50
# 821/821 [==============================] - 0s 235us/step - loss: 0.0019 - mean_squared_error: 0.0019 - mean_absolute_error: 0.0265 - mean_absolute_percentage_error: 9371.5816 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - val_mean_absolute_error: 0.0291 - val_mean_absolute_percentage_error: 18.1838
# Epoch 37/50
# 821/821 [==============================] - 0s 246us/step - loss: 0.0021 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0293 - mean_absolute_percentage_error: 5331.0025 - val_loss: 0.0053 - val_mean_squared_error: 0.0053 - val_mean_absolute_error: 0.0435 - val_mean_absolute_percentage_error: 27.5429
# Epoch 38/50
# 821/821 [==============================] - 0s 224us/step - loss: 0.0021 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0284 - mean_absolute_percentage_error: 21708.7838 - val_loss: 0.0042 - val_mean_squared_error: 0.0042 - val_mean_absolute_error: 0.0323 - val_mean_absolute_percentage_error: 21.2656
# Epoch 39/50
# 821/821 [==============================] - 0s 228us/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0285 - mean_absolute_percentage_error: 20762.5059 - val_loss: 0.0039 - val_mean_squared_error: 0.0039 - val_mean_absolute_error: 0.0303 - val_mean_absolute_percentage_error: 18.9354
# Epoch 40/50
# 821/821 [==============================] - 0s 226us/step - loss: 0.0022 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0297 - mean_absolute_percentage_error: 32977.0579 - val_loss: 0.0039 - val_mean_squared_error: 0.0039 - val_mean_absolute_error: 0.0296 - val_mean_absolute_percentage_error: 18.3014
# Epoch 41/50
# 821/821 [==============================] - 0s 227us/step - loss: 0.0023 - mean_squared_error: 0.0023 - mean_absolute_error: 0.0330 - mean_absolute_percentage_error: 16768.8601 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - val_mean_absolute_error: 0.0299 - val_mean_absolute_percentage_error: 17.3606
# Epoch 42/50
# 821/821 [==============================] - 0s 232us/step - loss: 0.0019 - mean_squared_error: 0.0019 - mean_absolute_error: 0.0270 - mean_absolute_percentage_error: 2651.4097 - val_loss: 0.0041 - val_mean_squared_error: 0.0041 - val_mean_absolute_error: 0.0329 - val_mean_absolute_percentage_error: 20.9273
# Epoch 43/50
# 821/821 [==============================] - 0s 224us/step - loss: 0.0018 - mean_squared_error: 0.0018 - mean_absolute_error: 0.0265 - mean_absolute_percentage_error: 19760.2706 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - val_mean_absolute_error: 0.0289 - val_mean_absolute_percentage_error: 17.5284
# Epoch 44/50
# 821/821 [==============================] - 0s 225us/step - loss: 0.0019 - mean_squared_error: 0.0019 - mean_absolute_error: 0.0262 - mean_absolute_percentage_error: 4466.5308 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - val_mean_absolute_error: 0.0290 - val_mean_absolute_percentage_error: 17.4402
# Epoch 45/50
# 821/821 [==============================] - 0s 225us/step - loss: 0.0022 - mean_squared_error: 0.0022 - mean_absolute_error: 0.0314 - mean_absolute_percentage_error: 16788.1946 - val_loss: 0.0040 - val_mean_squared_error: 0.0040 - val_mean_absolute_error: 0.0362 - val_mean_absolute_percentage_error: 20.3223
# Epoch 46/50
# 821/821 [==============================] - 0s 221us/step - loss: 0.0021 - mean_squared_error: 0.0021 - mean_absolute_error: 0.0302 - mean_absolute_percentage_error: 5901.5159 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - val_mean_absolute_error: 0.0287 - val_mean_absolute_percentage_error: 17.7653
# Epoch 47/50
# 821/821 [==============================] - 0s 223us/step - loss: 0.0019 - mean_squared_error: 0.0019 - mean_absolute_error: 0.0270 - mean_absolute_percentage_error: 10817.0510 - val_loss: 0.0038 - val_mean_squared_error: 0.0038 - val_mean_absolute_error: 0.0320 - val_mean_absolute_percentage_error: 21.6798
# Epoch 48/50
# 821/821 [==============================] - 0s 239us/step - loss: 0.0020 - mean_squared_error: 0.0020 - mean_absolute_error: 0.0282 - mean_absolute_percentage_error: 1844.8502 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - val_mean_absolute_error: 0.0290 - val_mean_absolute_percentage_error: 17.5321
# Epoch 49/50
# 821/821 [==============================] - 0s 223us/step - loss: 0.0018 - mean_squared_error: 0.0018 - mean_absolute_error: 0.0264 - mean_absolute_percentage_error: 1414.4913 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - val_mean_absolute_error: 0.0277 - val_mean_absolute_percentage_error: 16.9376
# Epoch 50/50
# 821/821 [==============================] - 0s 225us/step - loss: 0.0018 - mean_squared_error: 0.0018 - mean_absolute_error: 0.0260 - mean_absolute_percentage_error: 7876.2584 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - val_mean_absolute_error: 0.0289 - val_mean_absolute_percentage_error: 17.1647

# %% [markdown]
# Again, let's plot the loss vs epochs for the training and validation sets (the validation set is a subset of the training set, not the same as the 'test' set we will use later).

# %%
fig,ax = plt.subplots()

loss     = history.history['loss']
val_loss = history.history.get('val_loss')

x = range(1,len(loss)+1)
plt.plot(x,loss,    label='Training')
plt.plot(x,val_loss,label="Validation")

plt.xlabel('Epoch',ha='right',va='top',   position=(1,0))
plt.ylabel('Loss', ha='right',va='bottom',position=(0,1))

plt.legend(loc=0,numpoints=1)

# %%
predictions = model.predict(X_test_scale).flatten()  # convert the data back to the original scale
values      = np.divide((predictions - Y_test_scale.flatten()),Y_test_scale.flatten())        # offsets to compare predicted and actual value

# %%
# Prediction
fig,ax = plt.subplots(2,1,figsize=(8,8))

plt.subplot(2,1,1)
plt.hist(values,bins=20,normed=True)
plt.xlabel("(Pred-Real)/Real",position=(1,0),ha='right')
plt.ylabel("AU",position=(0,1),ha='right')

plt.subplot(2,1,2)
plt.scatter(predictions,Y_test_scale.flatten(),color='b',edgecolor='k',alpha=0.5,label="Test Dataset");
plt.plot(Y_test_scale.flatten(),Y_test_scale.flatten(),color='r',label="Perfect")
# plt.xlim(min(predictions)-10000,max(predictions)+10000)
# plt.ylim(0,max(Y_test)+20000)
plt.xlabel("Predicted Sale Price",position=(1,0),ha='right')
plt.ylabel("Real Sale Price",position=(0,1),ha='right')
plt.legend()

evs = explained_variance_score(Y_test,predictions)

print(r"Distribution = {0:.3f} $\pm$ {1:.4f} :: {2:.3f}".format(np.mean(values),np.std(values),evs))
# Out:
# Distribution = -0.012 $\pm$ 0.6552 :: 0.000

# %%
# Let's transform the target values back to the nominal scale and remake the plots
predictions = scaler_target.inverse_transform(model.predict(X_test_scale))  # convert the data back to the original scale
values      = np.divide((predictions.flatten() - Y_test),Y_test)        # offsets to compare predicted and actual value

# Prediction
fig,ax = plt.subplots(2,1,figsize=(8,8))

plt.subplot(2,1,1)
plt.hist(values,bins=20,normed=True)
plt.xlabel("(Pred-Real)/Real",position=(1,0),ha='right')
plt.ylabel("AU",position=(0,1),ha='right')

plt.subplot(2,1,2)
plt.scatter(predictions,Y_test,color='b',edgecolor='k',alpha=0.5,label="Test Dataset");
plt.plot(Y_test,Y_test,color='r',label="Perfect")
# plt.xlim(min(predictions)-10000,max(predictions)+10000)
# plt.ylim(0,max(Y_test)+20000)
plt.xlabel("Predicted Sale Price",position=(1,0),ha='right')
plt.ylabel("Real Sale Price",position=(0,1),ha='right')
plt.legend()

evs = explained_variance_score(Y_test,predictions)

print(r"Distribution = {0:.3f} $\pm$ {1:.4f} :: {2:.3f}".format(np.mean(values),np.std(values),evs))
# Out:
# Distribution = -0.021 $\pm$ 0.1711 :: 0.832

# %% [markdown]
# After scaling the inputs, the performance is noticeably better -- which seems reasonable because now the weights are being updated by values on the same scale, and individual parameters aren't dominating the training.

# %% [markdown]
# #### Conclusions
#
# Of course, there are _many_ hyperparameters that we can adjust to optimize performance and prevent overtraining.
# With time, I'll revisit this to have a better idea as to what each parameter can affect.
#
# After testing the different methods, it's easy to see how neural networks are more popular -- the great performance and easy-to-use API from `keras` creates a very low barrier to entry!
#
# The next notebooks will tackle different datasets from Kaggle -- feel free to also check out the `Julia` notebooks (where I'm trying to learn the Julia language for data science).
